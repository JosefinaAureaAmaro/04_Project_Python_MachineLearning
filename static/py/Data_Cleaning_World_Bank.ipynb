# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 1: Import Data

# %%
#to read csv of data
df= pd.read_csv('../../../WDIData.csv')

#to read csv of country names
df_country_names= pd.read_csv('../data/WDI_Country_Code_and_Names.csv',encoding = "ISO-8859-1")

#to read csv of indicators
df_list_indicators = pd.read_csv('../data/WDI_list_of_reviewed_indicators.csv')

# %% [markdown]
# ### Step 2: Data Cleaning

# %%
#to grab the headers of the dataset
df_headers=list(df.columns.values)

# %%
#only pull the headers that are years
df_years = df_headers[-59:]

# %%
#only select previous years before 2010
df_years_drop = df_years[0:50]
#to make column '2018' a list
df_years_drop_2018 = list([df_years[-1]])

# to combine lists of years into 1 drop line
df_drop = df_years_drop + df_years_drop_2018

# %%
#to drop the years and create a summarized df
df_columns_removed = df.drop(df_drop,axis=1)
df_columns_removed.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#         2010       2011       2012       2013       2014       2015  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2  82.407647  82.827636  83.169227  83.587141  83.954293  84.230630
# 3  86.136134  86.782683  87.288244  88.389705  88.076774  88.517967
# 4  74.543489  75.770972  76.772916  78.839139  77.487377  78.564439
#
#         2016  2017
# 0        NaN   NaN
# 1        NaN   NaN
# 2  84.570425   NaN
# 3  88.768654   NaN
# 4  78.958780   NaN

# %%
#to preview df_country_names
df_country_names.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code
# 0           AW
# 1           AF
# 2           AO
# 3           AL
# 4           AD

# %%
#make a list of country short name
country_short_names = list(df_country_names['Short Name'])

# %%
#filter df by short names list
df_filter_cols_nd_cols_rem = df_columns_removed.loc[df_columns_removed['Country Name'].isin(country_short_names)]

# %%
df_filter_cols_nd_cols_rem.head()
# Out:
#       Country Name Country Code  \
# 75153  Afghanistan          AFG
# 75154  Afghanistan          AFG
# 75155  Afghanistan          AFG
# 75156  Afghanistan          AFG
# 75157  Afghanistan          AFG
#
#                                           Indicator Name     Indicator Code  \
# 75153  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05
# 75154  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05
# 75155  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 75156            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 75157  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#         2010       2011   2012       2013   2014  2015       2016  2017
# 75153    NaN        NaN    NaN        NaN    NaN   NaN        NaN   NaN
# 75154    NaN        NaN    NaN        NaN    NaN   NaN        NaN   NaN
# 75155  20.68  22.330000  24.08  26.170000  27.99  30.1  32.440000   NaN
# 75156  42.70  43.222019  69.10  67.259552  89.50  71.5  84.137138   NaN
# 75157  32.40  33.380110  63.80  58.423667  87.80  64.2  78.961074   NaN

# %%
df_list_indicators.head()
# Out:
#                                       Indicator Name
# 0                            GDP (constant 2010 US$)
# 1  Population density (people per sq. km of land ...
# 2  Literacy rate, adult total (% of people ages 1...
# 3  Probability of dying at age 5-14 years (per 1,...
# 4                   GINI index (World Bank estimate)

# %%
indicators =  list(df_list_indicators['Indicator Name'])
indicators
# Out:
# ['GDP (constant 2010 US$)',
#  'Population density (people per sq. km of land area)',
#  'Literacy rate, adult total (% of people ages 15 and above)',
#  'Probability of dying at age 5-14 years (per 1,000 children age 5)',
#  'GINI index (World Bank estimate)']

# %%
#filter by indicators
df_countries_indiciator = df_filter_cols_nd_cols_rem.loc[df_filter_cols_nd_cols_rem['Indicator Name'].isin(indicators)]

# %%
df_countries_indiciator.head()
# Out:
#       Country Name Country Code  \
# 75666  Afghanistan          AFG
# 75693  Afghanistan          AFG
# 75928  Afghanistan          AFG
# 76284  Afghanistan          AFG
# 76438  Afghanistan          AFG
#
#                                           Indicator Name  Indicator Code  \
# 75666                            GDP (constant 2010 US$)  NY.GDP.MKTP.KD
# 75693                   GINI index (World Bank estimate)     SI.POV.GINI
# 75928  Literacy rate, adult total (% of people ages 1...  SE.ADT.LITR.ZS
# 76284  Population density (people per sq. km of land ...     EN.POP.DNST
# 76438  Probability of dying at age 5-14 years (per 1,...     SH.DYN.0514
#
#                2010          2011          2012          2013          2014  \
# 75666  1.585657e+10  1.592418e+10  1.795488e+10  1.896048e+10  1.947707e+10
# 75693           NaN           NaN           NaN           NaN           NaN
# 75928           NaN  3.174112e+01           NaN           NaN           NaN
# 76284  4.411844e+01  4.550531e+01  4.701920e+01  4.860412e+01  5.017618e+01
# 76438  1.150000e+01           NaN           NaN           NaN           NaN
#
#                2015          2016          2017
# 75666  1.975974e+10  2.020638e+10  2.074494e+10
# 75693           NaN           NaN           NaN
# 75928           NaN           NaN           NaN
# 76284  5.167493e+01  5.308341e+01  5.442221e+01
# 76438  1.040000e+01           NaN  9.900000e+00

# %%
#remove unnessecary columns
df_wdi = df_countries_indiciator.drop(['Country Code','Indicator Code'],axis=1)

# %%
df_wdi.to_csv('../../../WDI_Happiness_Data.csv', sep=',' , encoding= 'utf-8', index=False)

# %% [markdown]
# ### Step 4: Reshaping the Data

# %% [markdown]
# WHERE THE CHAOS BEGINS

# %%
df_wdi.head()
# Out:
#       Country Name                                     Indicator Name  \
# 75666  Afghanistan                            GDP (constant 2010 US$)
# 75693  Afghanistan                   GINI index (World Bank estimate)
# 75928  Afghanistan  Literacy rate, adult total (% of people ages 1...
# 76284  Afghanistan  Population density (people per sq. km of land ...
# 76438  Afghanistan  Probability of dying at age 5-14 years (per 1,...
#
#                2010          2011          2012          2013          2014  \
# 75666  1.585657e+10  1.592418e+10  1.795488e+10  1.896048e+10  1.947707e+10
# 75693           NaN           NaN           NaN           NaN           NaN
# 75928           NaN  3.174112e+01           NaN           NaN           NaN
# 76284  4.411844e+01  4.550531e+01  4.701920e+01  4.860412e+01  5.017618e+01
# 76438  1.150000e+01           NaN           NaN           NaN           NaN
#
#                2015          2016          2017
# 75666  1.975974e+10  2.020638e+10  2.074494e+10
# 75693           NaN           NaN           NaN
# 75928           NaN           NaN           NaN
# 76284  5.167493e+01  5.308341e+01  5.442221e+01
# 76438  1.040000e+01           NaN  9.900000e+00

# %%
years = ['2010','2011','2012','2013','2014']

# %%
wdi_series = df_wdi[['Country Name', 'Indicator Name', '2010']]
wdi_series
# Out:
#        Country Name                                     Indicator Name  \
# 75666   Afghanistan                            GDP (constant 2010 US$)
# 75693   Afghanistan                   GINI index (World Bank estimate)
# 75928   Afghanistan  Literacy rate, adult total (% of people ages 1...
# 76284   Afghanistan  Population density (people per sq. km of land ...
# 76438   Afghanistan  Probability of dying at age 5-14 years (per 1,...
# ...             ...                                                ...
# 421050     Zimbabwe                            GDP (constant 2010 US$)
# 421077     Zimbabwe                   GINI index (World Bank estimate)
# 421312     Zimbabwe  Literacy rate, adult total (% of people ages 1...
# 421668     Zimbabwe  Population density (people per sq. km of land ...
# 421822     Zimbabwe  Probability of dying at age 5-14 years (per 1,...
#
#                 2010
# 75666   1.585657e+10
# 75693            NaN
# 75928            NaN
# 76284   4.411844e+01
# 76438   1.150000e+01
# ...              ...
# 421050  1.204166e+10
# 421077           NaN
# 421312           NaN
# 421668  3.641287e+01
# 421822  1.590000e+01
#
# [985 rows x 3 columns]

# %%
wdi = pd.pivot_table(wdi_series, values='2010', index=['Country Name'], columns=['Indicator Name'], aggfunc= np.sum)

# %%
wdi.head()
# Out:
# Indicator Name  GDP (constant 2010 US$)  GINI index (World Bank estimate)  \
# Country Name
# Afghanistan                1.585657e+10                               0.0
# Albania                    1.192696e+10                               0.0
# Algeria                    1.612070e+11                               0.0
# American Samoa             5.760000e+08                               0.0
# Andorra                    3.355695e+09                               0.0
#
# Indicator Name  Literacy rate, adult total (% of people ages 15 and above)  \
# Country Name
# Afghanistan                                                   0.0
# Albania                                                       0.0
# Algeria                                                       0.0
# American Samoa                                                0.0
# Andorra                                                       0.0
#
# Indicator Name  Population density (people per sq. km of land area)  \
# Country Name
# Afghanistan                                             44.118443
# Albania                                                106.314635
# Algeria                                                 15.164391
# American Samoa                                         278.185000
# Andorra                                                179.678723
#
# Indicator Name  Probability of dying at age 5-14 years (per 1,000 children age 5)
# Country Name
# Afghanistan                                                  11.5
# Albania                                                       2.8
# Algeria                                                       4.3
# American Samoa                                                0.0
# Andorra                                                       1.0

# %%
wdi.to_csv('../../../WDI_Data_Happiness_Table.csv', sep=',' , encoding= 'utf-8', index=False)
