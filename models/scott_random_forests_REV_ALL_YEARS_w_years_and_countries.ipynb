# %%
#import dependencies 

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import seaborn as sns; sns.set(style="ticks", color_codes=True)
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.simplefilter('ignore')

# %%
# read in CSVs for all availables years

raw_2010_economic_data = pd.read_csv('Machine_Learning_Dataset_2010.csv')
raw_2011_economic_data = pd.read_csv('Machine_Learning_Dataset_2011.csv')
raw_2012_economic_data = pd.read_csv('Machine_Learning_Dataset_2012.csv')
raw_2013_economic_data = pd.read_csv('Machine_Learning_Dataset_2013.csv')
raw_2014_economic_data = pd.read_csv('Machine_Learning_Dataset_2014.csv')
raw_2015_economic_data = pd.read_csv('Machine_Learning_Dataset_2015.csv')
raw_2016_economic_data = pd.read_csv('Machine_Learning_Dataset_2016.csv')
raw_2017_economic_data = pd.read_csv('Machine_Learning_Dataset_2017.csv')

# %%
# make a list of dataframes

df_list = [raw_2010_economic_data, 
           raw_2011_economic_data,
           raw_2012_economic_data,
           raw_2013_economic_data,
           raw_2014_economic_data,
           raw_2015_economic_data,
           raw_2016_economic_data,
           raw_2017_economic_data]

# %%
# loop through dataframes and drop columns with null values

for df in df_list:
    df.dropna(axis='columns', inplace=True)

# %%
# loop through dataframes and drop any irrelevant or problematic columns

for df in df_list:
    df.drop(["Literacy rate, adult total (% of people ages 15 and above)",
              "GINI index (World Bank estimate)_x",
              "Mortality Causes",
  #            "Year",
  #            "Negative affect",
  #            "Positive affect",
  #            "Delivery Quality",
  #            "Standard deviation of ladder by country-year",
              "Standard deviation/Mean of ladder by country-year"], 
              axis=1, inplace=True)

# %%
# concatenate the dataframes into one

unified_df = pd.concat([raw_2010_economic_data, 
                        raw_2011_economic_data,
                        raw_2012_economic_data,
                        raw_2013_economic_data,
                        raw_2014_economic_data,
                        raw_2015_economic_data,
                        raw_2016_economic_data,
                        raw_2017_economic_data], ignore_index=True)

unified_df.head()
# Out:
#    Avg. Wages (Annual)  Avg. Work Hours (Annual)  COU  \
# 0          52252.97944                   1699.94  AUS
# 1          50096.71444                   1557.00  AUT
# 2          50872.48700                   1546.00  BEL
# 3          45502.56024                   1715.00  CAN
# 4          24960.82175                   2070.00  CHL
#
#    Confidence in national government    Country  Delivery Quality  \
# 0                           0.609753  Australia          1.815898
# 1                           0.486447    Austria          1.670085
# 2                           0.336516    Belgium          1.445168
# 3                           0.551076     Canada          1.838644
# 4                           0.478706      Chile          1.385961
#
#    Democratic Quality  Freedom to make life choices  GDP (constant 2010 US$)  \
# 0            1.154313                      0.932059             1.144260e+12
# 1            1.291470                      0.895980             3.918930e+11
# 2            1.085667                      0.806930             4.835480e+11
# 3            1.144457                      0.933949             1.613460e+12
# 4            0.887607                      0.786367             2.185380e+11
#
#    GINI index (World Bank estimate), average 2000-16  ...  Log GDP per capita  \
# 0                                                NaN  ...           10.632582
# 1                                                NaN  ...           10.676744
# 2                                                NaN  ...           10.623421
# 3                                                NaN  ...           10.613968
# 4                                                NaN  ...            9.875194
#
#    Negative affect  Perceptions of corruption  \
# 0         0.220073                   0.366127
# 1         0.155793                   0.546145
# 2         0.240364                   0.697366
# 3         0.233113                   0.412660
# 4         0.300117                   0.701825
#
#    Population density (people per sq. km of land area)  Positive affect  \
# 0                                           2.867859           0.834236
# 1                                         101.287430           0.814719
# 2                                         359.827807           0.828259
# 3                                           3.739510           0.878868
# 4                                          22.854905           0.809173
#
#    Probability of dying at age 5-14 years (per 1,000 children age 5)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.1
# 4                                                1.6
#
#    Social support  Standard deviation of ladder by country-year  Year  \
# 0        0.954520                                      1.737802  2010
# 1        0.914193                                      1.753248  2010
# 2        0.930570                                      1.603352  2010
# 3        0.953765                                      1.749785  2010
# 4        0.856955                                      2.183491  2010
#
#    gini of household income reported in Gallup, by wp5-year
# 0                                           0.412946
# 1                                           0.367440
# 2                                           0.393781
# 3                                           0.710133
# 4                                           0.452482
#
# [5 rows x 23 columns]

# %%
unified_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 23 columns):
# Avg. Wages (Annual)                                                  216 non-null float64
# Avg. Work Hours (Annual)                                             216 non-null float64
# COU                                                                  216 non-null object
# Confidence in national government                                    216 non-null float64
# Country                                                              216 non-null object
# Delivery Quality                                                     216 non-null float64
# Democratic Quality                                                   216 non-null float64
# Freedom to make life choices                                         216 non-null float64
# GDP (constant 2010 US$)                                              216 non-null float64
# GINI index (World Bank estimate), average 2000-16                    5 non-null float64
# Generosity                                                           183 non-null float64
# Healthy life expectancy at birth                                     216 non-null float64
# Life Ladder                                                          216 non-null float64
# Log GDP per capita                                                   216 non-null float64
# Negative affect                                                      216 non-null float64
# Perceptions of corruption                                            216 non-null float64
# Population density (people per sq. km of land area)                  216 non-null float64
# Positive affect                                                      216 non-null float64
# Probability of dying at age 5-14 years (per 1,000 children age 5)    216 non-null float64
# Social support                                                       216 non-null float64
# Standard deviation of ladder by country-year                         216 non-null float64
# Year                                                                 216 non-null int64
# gini of household income reported in Gallup, by wp5-year             216 non-null float64
# dtypes: float64(20), int64(1), object(2)
# memory usage: 38.9+ KB

# %%
# do another pass to drop null vaues

unified_df.dropna(axis='columns', inplace=True)
unified_df.head()
# Out:
#    Avg. Wages (Annual)  Avg. Work Hours (Annual)  COU  \
# 0          52252.97944                   1699.94  AUS
# 1          50096.71444                   1557.00  AUT
# 2          50872.48700                   1546.00  BEL
# 3          45502.56024                   1715.00  CAN
# 4          24960.82175                   2070.00  CHL
#
#    Confidence in national government    Country  Delivery Quality  \
# 0                           0.609753  Australia          1.815898
# 1                           0.486447    Austria          1.670085
# 2                           0.336516    Belgium          1.445168
# 3                           0.551076     Canada          1.838644
# 4                           0.478706      Chile          1.385961
#
#    Democratic Quality  Freedom to make life choices  GDP (constant 2010 US$)  \
# 0            1.154313                      0.932059             1.144260e+12
# 1            1.291470                      0.895980             3.918930e+11
# 2            1.085667                      0.806930             4.835480e+11
# 3            1.144457                      0.933949             1.613460e+12
# 4            0.887607                      0.786367             2.185380e+11
#
#    Healthy life expectancy at birth  ...  Log GDP per capita  Negative affect  \
# 0                         72.199997  ...           10.632582         0.220073
# 1                         71.400002  ...           10.676744         0.155793
# 2                         70.800003  ...           10.623421         0.240364
# 3                         72.199997  ...           10.613968         0.233113
# 4                         68.900002  ...            9.875194         0.300117
#
#    Perceptions of corruption  \
# 0                   0.366127
# 1                   0.546145
# 2                   0.697366
# 3                   0.412660
# 4                   0.701825
#
#    Population density (people per sq. km of land area)  Positive affect  \
# 0                                           2.867859           0.834236
# 1                                         101.287430           0.814719
# 2                                         359.827807           0.828259
# 3                                           3.739510           0.878868
# 4                                          22.854905           0.809173
#
#    Probability of dying at age 5-14 years (per 1,000 children age 5)  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.1
# 4                                                1.6
#
#    Social support  Standard deviation of ladder by country-year  Year  \
# 0        0.954520                                      1.737802  2010
# 1        0.914193                                      1.753248  2010
# 2        0.930570                                      1.603352  2010
# 3        0.953765                                      1.749785  2010
# 4        0.856955                                      2.183491  2010
#
#    gini of household income reported in Gallup, by wp5-year
# 0                                           0.412946
# 1                                           0.367440
# 2                                           0.393781
# 3                                           0.710133
# 4                                           0.452482
#
# [5 rows x 21 columns]

# %%
# rename column for easier viz

renamed_unified_df = unified_df.rename(columns={"Life Ladder": "Happiness Index",
                                               "gini of household income reported in Gallup, by wp5-year": "Gini household income",
                                               "Population density (people per sq. km of land area)": "Population density",
                                               "Standard deviation of ladder by country-year": "Standard deviation of ladder",
                                               "Probability of dying at age 5-14 years (per 1,000 children age 5)": "Probability of dying at age 5-14"})

# %%
# output this dataframe to CSV for use elsewhere

renamed_unified_df.to_csv("countries_and_econ_data_for_tableau.csv", index=True, header=True)
